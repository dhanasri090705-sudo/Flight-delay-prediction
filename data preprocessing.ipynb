# %%
print("Flight delay prediction using machine learning")
# Out:
# Flight delay prediction using machine learning

# %% [markdown]
# data collection loading

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Internship/Flight delay prediction using machine learning/dataset.csv")
# Out:
# /tmp/ipython-input-1464250590.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/drive/MyDrive/Internship/Flight delay prediction using machine learning/dataset.csv")

# %%
df
# Out:
#          is_delay    Year  FlightDate Reporting_Airline Origin OriginState  \
# 0             1.0  2014.0  01-01-2014                UA    LAX          CA
# 1             0.0  2014.0  01-01-2014                AA    IAH          TX
# 2             1.0  2014.0  01-01-2014                AA    LAX          CA
# 3             1.0  2014.0  01-01-2014                AA    DFW          TX
# 4             0.0  2014.0  01-01-2014                AA    DFW          TX
# ...           ...     ...         ...               ...    ...         ...
# 1048570       NaN     NaN         NaN               NaN    NaN         NaN
# 1048571       NaN     NaN         NaN               NaN    NaN         NaN
# 1048572       NaN     NaN         NaN               NaN    NaN         NaN
# 1048573       NaN     NaN         NaN               NaN    NaN         NaN
# 1048574       NaN     NaN         NaN               NaN    NaN         NaN
#
#         Dest DestState  CRSDepTime  Cancelled  Diverted  Distance  \
# ...

# %%
df.head()
# Out:
#    is_delay    Year  FlightDate Reporting_Airline Origin OriginState Dest  \
# 0       1.0  2014.0  01-01-2014                UA    LAX          CA  ORD
# 1       0.0  2014.0  01-01-2014                AA    IAH          TX  DFW
# 2       1.0  2014.0  01-01-2014                AA    LAX          CA  ORD
# 3       1.0  2014.0  01-01-2014                AA    DFW          TX  LAX
# 4       0.0  2014.0  01-01-2014                AA    DFW          TX  CLT
#
#   DestState  CRSDepTime  Cancelled  Diverted  Distance  DistanceGroup  \
# 0        IL       900.0        0.0       0.0    1744.0            7.0
# 1        TX      1750.0        0.0       0.0     224.0            1.0
# 2        IL      1240.0        0.0       0.0    1744.0            7.0
# 3        CA      1905.0        0.0       0.0    1235.0            5.0
# 4        NC      1115.0        0.0       0.0     936.0            4.0
#
#    ArrDelay  ArrDelayMinutes  AirTime  Unnamed: 16 Unnamed: 17
# ...

# %%
df.tail()
# Out:
#          is_delay  Year FlightDate Reporting_Airline Origin OriginState Dest  \
# 1048570       NaN   NaN        NaN               NaN    NaN         NaN  NaN
# 1048571       NaN   NaN        NaN               NaN    NaN         NaN  NaN
# 1048572       NaN   NaN        NaN               NaN    NaN         NaN  NaN
# 1048573       NaN   NaN        NaN               NaN    NaN         NaN  NaN
# 1048574       NaN   NaN        NaN               NaN    NaN         NaN  NaN
#
#         DestState  CRSDepTime  Cancelled  Diverted  Distance  DistanceGroup  \
# 1048570       NaN         NaN        NaN       NaN       NaN            NaN
# 1048571       NaN         NaN        NaN       NaN       NaN            NaN
# 1048572       NaN         NaN        NaN       NaN       NaN            NaN
# 1048573       NaN         NaN        NaN       NaN       NaN            NaN
# 1048574       NaN         NaN        NaN       NaN       NaN            NaN
#
# ...
